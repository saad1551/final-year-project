# %%
# CORE
MODEL_ID = "meta-llama/Llama-3.1-8B"
FINETUNED_REPO = "saadashraf87/llama-3-on-policy-rl"
OUTPUT_DIR = "/models/llama-3-on-policy-rl"
HF_TOKEN = None
DATASET_NAME = "data-for-agents/insta-150k-v3"
PRECISION = "fp16"
SAFE_SERIALIZATION = True

USE_LORA = True
LORA_R = 8
LORA_ALPHA = 16
LORA_DROPOUT = 0.05
LORA_MERGE_AT_SAVE = True

SFT_WARMUP = True
SFT_EPOCHS = 1
SFT_BATCH_SIZE = 4
SFT_LR = 2e-4

PPO_STEPS = 2000
PPO_BATCH_SIZE = 64
PPO_FORWARD_BATCH_SIZE = 4
PPO_EPOCHS = 4
PPO_LR = 1.41e-5
PPO_CLIP_RANGE = 0.2
KL_COEFF = 0.02
GAMMA = 1.0
LAMBDA = 0.95
ROLLOUT_MAXLEN = 512
SAVE_EVERY_N_UPDATES = 1

REWARD_MODEL = None

OUTPUT_INTERMEDIATE_CHECKPOINTS = True

# %%
from datasets import load_dataset

# %%
dataset = load_dataset(DATASET_NAME)
